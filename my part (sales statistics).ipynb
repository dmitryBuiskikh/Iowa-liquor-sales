# %%
import dask.dataframe as dd
import pandas as pd

# %%
df = dd.read_csv("Data/liquor_trimmed.csv",engine="python",
            error_bad_lines=False,dtype={
       'Bottles Sold': 'float64',
       'County Number': 'object',
       'Item Number': 'object',
       'Pack': 'float64',
       'Store Number': 'object',
       'Unnamed: 0': 'object',
       'Vendor Number': 'object',
        'Bottle Volume (ml)': 'float64',
            "Zip Code": "object"},
                
                )
#df = dd.read_csv("Data/liquor_trimmed.csv")
df.head()
# Out:
# Skipping line 941: unexpected end of data
#   Invoice/Item Number        Date Store Number                   Store Name  \
# 0     INV-02190200029  12/15/2016         2593  Hy-Vee Food Store / Carroll
# 1     INV-02190200030  12/15/2016         2593  Hy-Vee Food Store / Carroll
# 2     INV-02190200031  12/15/2016         2593  Hy-Vee Food Store / Carroll
# 3     INV-02190200032  12/15/2016         2593  Hy-Vee Food Store / Carroll
# 4     INV-02190200033  12/15/2016         2593  Hy-Vee Food Store / Carroll
#
#                   Address     City Zip Code  \
# 0  905 US Highway 30 West  Carroll    51401
# 1  905 US Highway 30 West  Carroll    51401
# 2  905 US Highway 30 West  Carroll    51401
# 3  905 US Highway 30 West  Carroll    51401
# 4  905 US Highway 30 West  Carroll    51401
#
#                                       Store Location County Number   County  \
# 0  905 US Highway 30 West\nCarroll 51401\n(42.070...            14  CARROLL
# 1  905 US Highway 30 West\nCarroll 51401\n(42.070...            14  CARROLL
# 2  905 US Highway 30 West\nCarroll 51401\n(42.070...            14  CARROLL
# 3  905 US Highway 30 West\nCarroll 51401\n(42.070...            14  CARROLL
# 4  905 US Highway 30 West\nCarroll 51401\n(42.070...            14  CARROLL
#
#    ...  Item Number             Item Description Pack Bottle Volume (ml)  \
# 0  ...        24458        Kessler Blend Whiskey  6.0             1750.0
# 1  ...        25608  Seagrams 7 Crown Bl Whiskey  6.0             1750.0
# 2  ...         4798            Cutty Sark Scotch  6.0             1750.0
# 3  ...         5288            J & B Rare Scotch  6.0             1750.0
# 4  ...         5635              Monkey Shoulder  6.0              750.0
#
#   State Bottle Cost State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0            $11.01              $16.52           2.0          $99.12
# 1            $11.96              $17.94           3.0         $107.64
# 2            $20.05              $30.08           1.0         $180.48
# 3            $22.50              $33.75           1.0         $202.50
# 4            $17.50              $26.25           2.0         $157.50
#
#   Volume Sold (Liters) Volume Sold (Gallons)
# 0                 3.50                  0.92
# 1                 5.25                  1.38
# 2                 1.75                  0.46
# 3                 1.75                  0.46
# 4                 1.50                  0.39
#
# [5 rows x 24 columns]

# %%
df.compute().shape
# Out:
# Skipping line 232528: unexpected end of data
# Skipping line 232849: unexpected end of data
# Skipping line 2: ',' expected after '"'
# Skipping line 4: ',' expected after '"'
# Skipping line 6: ',' expected after '"'
